# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from typing import List

# %%
nums = [1, 2, 3, 4]
nums_2 = [10, 20, 30, 40, 50]

# %%
a = nums[:].pop()

# %%
a = 'sushant shewale'

# %%
a.split(' ')[0].upper()
# Out:
# 'SUSHANT'

# %%
b = a.replace('sushant', 'sushant shewale')
a, b
# Out:
# ('sushant shewale', 'sushant shewale shewale')

# %%
a * 2
# Out:
# 'sushant shewalesushant shewale'

# %%
a.replace('sus', 'sss')
# Out:
# 'ssshant shewale'

# %%
str.replace(a, 'sus', 'sss')
# Out:
# 'ssshant shewale'
